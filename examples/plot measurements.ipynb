# %%
import pandas as pd
df = pd.read_excel(r'e:\LocalData\Programming\Python\surfalize\data\results_fft_morph_depth.xlsx')

# %%
import matplotlib.pyplot as plt
# Plot pulses vs depth
plt.scatter(df['Pulses'], df['depth'])
plt.xlabel('Pulses')
plt.ylabel('Depth')
plt.title('Pulses vs Depth')
plt.show()
